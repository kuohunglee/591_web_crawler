# %%
import pandas as pd
import numpy as np

# %%
govhouse= pd.read_csv('D:/資策會期末專題資料/房地產/新增資料夾/a_lvr_land_a.csv')

# %%
import pprint
n=govhouse.head().columns
pd.DataFrame(n)
# Out:
#                0
# 0           鄉鎮市區
# 1           交易標的
# 2   土地區段位置建物區段門牌
# 3    土地移轉總面積平方公尺
# 4       都市土地使用分區
# 5      非都市土地使用分區
# 6      非都市土地使用編定
# 7          交易年月日
# 8          交易筆棟數
# 9           移轉層次
# 10          總樓層數
# 11          建物型態
# 12          主要用途
# 13          主要建材
# 14        建築完成年月
# 15   建物移轉總面積平方公尺
# 16      建物現況格局-房
# 17      建物現況格局-廳
# 18      建物現況格局-衛
# 19     建物現況格局-隔間
# 20        有無管理組織
# 21           總價元
# 22       單價元平方公尺
# 23          車位類別
# 24   車位移轉總面積平方公尺
# 25         車位總價元
# 26            備註
# 27            編號

# %%
oldhouse_591= pd.read_csv('D:/資策會期末專題資料/房地產/591/台北市中古屋爬蟲/591_台北中古屋房價_2020719/591_house_0_1000.csv')

# %%
m=oldhouse_591
m_df=pd.DataFrame(m)

# %%
m_df.iloc[:,:]
# Out:
#         房價      單價         格局   屋齡          權狀坪數       樓層            社區  \
# 0     9988  114.56  5房3廳3衛3陽台  14年    86.3坪(含車位)    7F/7F        九昱仁愛怡園
# 1     3308   84.98  3房2廳2衛1陽台   1年   41.18坪(含車位)  10F/18F            富饒
# 2     5500   85.81  4房2廳2衛2陽台   1年   74.37坪(含車位)  10F/18F        正隆ONE+
# 3     5650   86.35  4房2廳2衛2陽台  10年   65.43坪(含車位)   7F/10F          平安新城
# 4     2380   80.62  2房2廳1衛1陽台   3年    31.4坪(含車位)    6F/7F  樂樂Smart Home
# ..     ...     ...        ...  ...           ...      ...           ...
# 980   5088  133.93  2房1廳1衛2陽台  24年   50.17坪(含車位)   4F/10F      天母強者薔薇華廈
# 981   2980   87.42  3房2廳2衛1陽台  37年        34.09坪  12F/12F       忠駝國宅乙丙區
# 982  10500   85.14     3房2廳3衛   6年  123.33坪(含車位)   5F/15F          天母築萃
# 983   5555  107.99  4房2廳2衛1陽台  38年        51.44坪  14F/14F        仁愛三青D棟
# 984   1688   59.05  3房2廳2衛1陽台  40年        28.58坪   5F/12F        亞洲觀光大廈
#
#                      地址  現況    型態  ...  公設比      主建物     共用部分    附屬建物  \
# ...

# %%
nannum = m_df.isna().sum()
nannum
# Out:
# 房價        0
# 單價        0
# 格局        6
# 屋齡        6
# 權狀坪數      6
# 樓層        6
# 社區      160
# 地址        0
# 現況        4
# 型態        6
# 裝潢程度      6
# 管理費     201
# 帶租約       6
# 法定用途    114
# 車位      143
# 公設比     295
# 主建物     160
# 共用部分    270
# 附屬建物    215
# 土地坪數    285
# 朝向      231
# 車位種類    979
# 車位坪數    980
# 車位類型    979
# 現況坪數    960
# dtype: int64

# %%
m_df.columns
# Out:
# Index(['房價', '單價', '格局', '屋齡', '權狀坪數', '樓層', '社區', '地址', '現況', '型態', '裝潢程度',
#        '管理費', '帶租約', '法定用途', '車位', '公設比', '主建物', '共用部分', '附屬建物', '土地坪數', '朝向',
#        '車位種類', '車位坪數', '車位類型', '現況坪數'],
#       dtype='object')

# %%
columns = ['車位種類', '車位坪數','車位類型','現況坪數','社區','現況坪數']
new_m_df=m_df.drop(columns, axis=1)

# %%
new_m_df.to_csv("D:\\爬蟲\\591_house_new_0_1000.csv",index=False, encoding="utf-8")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-79-a9570ce75ef0> in <module>
# ----> 1 new_m_df.to_csv("D:\\爬蟲\\591_house_new_0_1000.csv",index=False, encoding="utf-8")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
# ...

# %%
new_m_df
# Out:
#         房價      單價         格局   屋齡          權狀坪數       樓層                  地址  \
# 0     9988  114.56  5房3廳3衛3陽台  14年    86.3坪(含車位)    7F/7F      台北市大安區仁愛路三段24巷
# 1     3308   84.98  3房2廳2衛1陽台   1年   41.18坪(含車位)  10F/18F           台北市松山區饒河街
# 2     5500   85.81  4房2廳2衛2陽台   1年   74.37坪(含車位)  10F/18F           台北市松山區饒河街
# 3     5650   86.35  4房2廳2衛2陽台  10年   65.43坪(含車位)   7F/10F       台北市松山區延壽街330巷
# 4     2380   80.62  2房2廳1衛1陽台   3年    31.4坪(含車位)    6F/7F       台北市松山區寶清街101巷
# ..     ...     ...        ...  ...           ...      ...                 ...
# 980   5088  133.93  2房1廳1衛2陽台  24年   50.17坪(含車位)   4F/10F       台北市士林區天母西路50巷
# 981   2980   87.42  3房2廳2衛1陽台  37年        34.09坪  12F/12F  台北市信義區基隆路一段380巷16號
# 982  10500   85.14     3房2廳3衛   6年  123.33坪(含車位)   5F/15F    台北市士林區中山北路五段829巷
# 983   5555  107.99  4房2廳2衛1陽台  38年        51.44坪  14F/14F         台北市大安區仁愛路四段
# 984   1688   59.05  3房2廳2衛1陽台  40年        28.58坪   5F/12F           台北市中山區長春路
#
# ...

# %%
new_m_df.shape
# Out:
# (985, 20)

# %%
oldhouse_591_1_2= pd.read_csv('D:/資策會期末專題資料/房地產/591/台北市中古屋爬蟲/591_台北中古屋房價_2020719/591_house_1000_2000.csv')

# %%
oldhouse_591_2_3= pd.read_csv('D:/資策會期末專題資料/房地產/591/台北市中古屋爬蟲/591_台北中古屋房價_2020719/591_house_2000_3000.csv')

# %%
oldhouse_591_3_4= pd.read_csv('D:/資策會期末專題資料/房地產/591/台北市中古屋爬蟲/591_台北中古屋房價_2020719/591_house_3000_4000.csv')

# %%
oldhouse_591_4_5= pd.read_csv('D:/資策會期末專題資料/房地產/591/台北市中古屋爬蟲/591_台北中古屋房價_2020719/591_house_4000_5000.csv')

# %%
oldhouse_591_5_6= pd.read_csv('D:/資策會期末專題資料/房地產/591/台北市中古屋爬蟲/591_台北中古屋房價_2020719/591_house_5000_6000.csv')

# %%
oldhouse_591_6_7= pd.read_csv('D:/資策會期末專題資料/房地產/591/台北市中古屋爬蟲/591_台北中古屋房價_2020719/591_house_6000_7000.csv')

# %%
oldhouse_591_7_8= pd.read_csv('D:/資策會期末專題資料/房地產/591/台北市中古屋爬蟲/591_台北中古屋房價_2020719/591_house_7000_8000.csv')

# %%
oldhouse_591_8_072= pd.read_csv('D:/資策會期末專題資料/房地產/591/台北市中古屋爬蟲/591_台北中古屋房價_2020719/591_house_8000_8072.csv')

# %%
oldhouse_591_072_9= pd.read_csv('D:/資策會期末專題資料/房地產/591/台北市中古屋爬蟲/591_台北中古屋房價_2020719/591_house_8072_9000.csv')

# %%
oldhouse_591_9_10= pd.read_csv('D:/資策會期末專題資料/房地產/591/台北市中古屋爬蟲/591_台北中古屋房價_2020719/591_house_9000_10000.csv')

# %%
oldhouse_591_10_10560= pd.read_csv('D:/資策會期末專題資料/房地產/591/台北市中古屋爬蟲/591_台北中古屋房價_2020719/591_house_10000_10560.csv')

# %%
columns = ['車位種類', '車位坪數','車位類型','現況坪數','社區','現況坪數']
new_m_df=m_df.drop(columns, axis=1)

# %%
m2=oldhouse_591_1_2
m2_df=pd.DataFrame(m2)

# %%
m3=oldhouse_591_3_4
m3_df=pd.DataFrame(m3)

# %%
m4=oldhouse_591_4_5
m4_df=pd.DataFrame(m4)

# %%
m5=oldhouse_591_5_6
m5_df=pd.DataFrame(m5)

# %%
m6=oldhouse_591_6_7
m6_df=pd.DataFrame(m6)

# %%
m7=oldhouse_591_7_8
m7_df=pd.DataFrame(m7)

# %%
m8=oldhouse_591_8_072
m8_df=pd.DataFrame(m8)

# %%
m9=oldhouse_591_9_10
m9_df=pd.DataFrame(m9)

# %%
m10=oldhouse_591_10_10560
m10_df=pd.DataFrame(m10)
m10
# Out:
#        房價      單價         格局   屋齡         權狀坪數      樓層      朝向      社區  \
# 0    1880   64.12     1房2廳2衛  17年       29.32坪  7F/25F    坐南朝北      天月
# 1    6670   68.66  2房2廳2衛2陽台  23年  97.14坪(含車位)  9F/16F    坐南朝北    至善天下
# 2     798   52.64  1房1廳1衛2陽台  20年       15.16坪  8F/13F    坐北朝南     掬水軒
# 3     918   59.92       2房2衛  42年       15.32坪   7F/8F    坐南朝北  北投公園大廈
# 4    1058   48.20  2房1廳1衛1陽台  26年       21.95坪   5F/8F  坐西南朝東北  山水雅都大廈
# ..    ...     ...        ...  ...          ...     ...     ...     ...
# 546  1180   68.33     1房1廳1衛  22年       17.27坪  7F/12F    坐西朝東  中山吉軒大廈
# 547  7700  117.52     3房2廳2衛  11年   72.1坪(含車位)   5F/7F    坐西朝東    燕庭大廈
# 548  7200  101.76     2房2廳2衛  10年  91.29坪(含車位)  6F/15F    坐東朝西    松江敦華
# 549  2380  100.14     2房1廳1衛   4年   34.5坪(含車位)  6F/10F    坐北朝南    中山凱宴
# 550  1188   68.77     1房1廳1衛  12年  19.48坪(含車位)   7F/7F    坐北朝南    麗池卡登
#
#                   地址  現況  ...                 車位  公設比      主建物     共用部分  \
# ...

# %%
m_total = pd.concat( [m, m2, m3, m4, m5, m6, m7, m8, m9, m10] )
oldh_total=m_total.reset_index()
oldh_total=oldh_total.drop(["index"], axis=1)
oldh_total.shape
# Out:
# (8556, 25)

# %%
oldh_total.to_csv('D:/資策會期末專題資料/房地產/591/台北市中古屋爬蟲/591_台北中古屋房價_2020719/591_old_house_8556.csv',index=False, encoding="utf-8")

# %%
columns = ['車位種類', '車位坪數','車位類型','現況坪數','社區','現況坪數']
oldh_total_edit=oldh_total.drop(columns, axis=1)
oldh_total_edit.shape
oldh_total_edit.isnull().sum()
oldh_total_edit.rename(columns={'房價':'Price', '單價':'Unit_Price', '格局':'Pattern', '屋齡':'Age','權狀坪數':'N_rights','地址':'Addr','現況':'Now_usage','型態':'Type','裝潢程度':'Decorate_de','管理費':'Manage_fee','法定用途':'Legal_p','車位':'P_sapce','公設比':'Public_ratio','主建物':'M_bulding','共用部分':'Shared_part','附屬建物':'Ancillary_building','土地坪數':'N_land','朝向':'Dir','帶租約':'With_lease','樓層':'Floor'}, inplace = True)

# %%
oldh_total_edit.isnull().sum()
# Out:
# Price                    0
# Unit_Price               0
# Pattern                 63
# Age                     58
# N_rights                58
# Floor                   58
# Addr                     0
# Now_usage               56
# Type                    58
# Decorate_de             59
# Manage_fee            2621
# With_lease              58
# Legal_p                329
# P_sapce                853
# Public_ratio          3429
# M_bulding             1719
# Shared_part           2992
# Ancillary_building    2395
# N_land                2181
# Dir                   2477
# dtype: int64

# %%
oldh_total_edit.dtypes
# Out:
# Price                   int64
# Unit_Price            float64
# Pattern                object
# Age                    object
# N_rights               object
# Floor                  object
# Addr                   object
# Now_usage              object
# Type                   object
# Decorate_de            object
# Manage_fee             object
# With_lease             object
# Legal_p                object
# P_sapce                object
# Public_ratio           object
# M_bulding              object
# Shared_part            object
# Ancillary_building     object
# N_land                 object
# Dir                    object
# dtype: object

# %%
oldh_total_edit.shape
# Out:
# (8556, 20)

# %%
oldh_total_edit.to_csv('D:/資策會期末專題資料/房地產/591/台北市中古屋爬蟲/591_台北中古屋房價_2020719/591_old_house_8556_drop_edc.csv',index=False, encoding="utf-8")

# %%
print(m.shape, m2.shape, m3.shape, m4.shape, m5.shape, m6.shape, m7.shape, m8.shape, m9.shape, m10.shape)
# Out:
# (985, 25) (996, 25) (996, 25) (995, 25) (986, 25) (989, 25) (994, 25) (71, 25) (993, 25) (551, 25)
